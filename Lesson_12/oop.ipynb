# %% [markdown]
# ### ООП(OOP) - Объектно ориентированное программирование
# Приципы ООП:
#
# Инкапсуляция (Encapsulation)
# Наследование (inheritance)
# Полиморфизм (Polymorphism)

# %% [markdown]
# ### Инкапсуляция
# Все данные объекта должны хранится в объекте. Никто не может изменить данные объекта без его ведома.

# %% [markdown]
# ### Наследование
# Объекты и их типы организуют иерархию типов. Дочерние типы наследуют свою функциональность от родительского класса, расширяя и дополняя её.

# %% [markdown]
# ### Полиморфизм
# Способность классов менять своё поведение в зависимости от типов операций и операндов. Полиморфизм в программировании реализуется через перегрузку метода, либо через его переопределение.

# %%
from abc import abstractmethod


class Group:
    pupils = True
    school_name = 42
    director = 'Marivanna'

    def __init__(self, title, pupils_count, group_leader):
        self.title = title
        self.pupils_count = pupils_count
        self.group_leader = group_leader


    def study(self):
        print('sit down and read')

    @abstractmethod
    def move(self):
        pass


class PrimaryGroup(Group):
    max_age = 11
    min_age = 6
    building_section = 'left'

    def __init__(self, title, pupils_count, group_leader, class_room):
        super().__init__(title, pupils_count, group_leader)
        self.class_room = class_room

    def move(self):
        print('Run fast')


class HighGroup(Group):
    max_age = 18
    min_age = 14

    def move(self):
        print('Go slowly')

class MediumGroup(Group):
    max_age = 15
    min_age = 10
# Out:
# 10000

# %%
first_a = PrimaryGroup('1 A',15, 'SD', 112)
first_a.class_room = 10000
print(first_a.class_room)
# Out:
# 10000

# %%
# data1.txt
{"Country": "Turkey", "avg_temp": 30}
# data2.txt
{"Country": "Greece", "avg_temp": 28}
# data3.txt
{"Country": "Poland", "avg_temp": 15, "min_temp": 2}
# Out:
# {'Country': 'Greece', 'avg_temp': 28}

# %%
import json

def read_file(filename):
    file_data = open(filename, 'r')
    # data = file_data.read()
    data = json.load(file_data)
    file_data.close()
    return data

data1 = read_file('data1.txt')
data2 = read_file('data2.txt')

print(data1['Country'])
print(data1['avg_temp'])
print(data2['Country'])
print(data2['avg_temp'])
# Out:
# Turkey
# 30
# Greece
# 28

# %%
class CountryData:
    def __init__(self, filename):
        self.filename = filename
        self.data = self.read_file()
        self.country = self.data['Country']
        self.__avg_temp = self.data['avg_temp']
        self.comfort = self.is_comfort()

    def read_file(self):
        file_data= open(self.filename, 'r')
        data = json.load(file_data)
        file_data.close()
        return data

    def is_comfort(self):
        return self.avg_temp > 25

# %%
data1 = CountryData('data1.txt')
print(data1.data)
print(data1.country)
# print(data1.avg_temp)
data2 = CountryData('data2.txt')
print(data2.country)
print(data1.comfort)
data1.__avg_temp = 2342342
print(data1.__avg_temp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 data1 = CountryData('data1.txt')
#       2 print(data1.data)
#       3 print(data1.country)
#
# Cell In[48], line 7, in CountryData.__init__(self, filename)
#       5 self.country = self.data['Country']
#       6 self.__avg_temp = self.data['avg_temp']
# ----> 7 self.comfort = self.is_comfort()
#
# Cell In[48], line 16, in CountryData.is_comfort(self)
#      15 def is_comfort(self):
# ---> 16     return self.avg_temp > 25
#
# AttributeError: 'CountryData' object has no attribute 'avg_temp'

# %%
class CountryDataWithMinTemp(CountryData):
    def __init__(self, filename):
        super().__init__(filename)
        self.min_temp = self.data['min_temp']

data3 = CountryDataWithMinTemp('data3.txt')
print(data3.avg_temp)
print(data3.min_temp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 6
#       3         super().__init__(filename)
#       4         self.min_temp = self.data['min_temp']
# ----> 6 data3 = CountryDataWithMinTemp('data3.txt')
#       7 print(data3.avg_temp)
#       8 print(data3.min_temp)
#
# Cell In[51], line 3, in CountryDataWithMinTemp.__init__(self, filename)
#       2 def __init__(self, filename):
# ----> 3     super().__init__(filename)
#       4     self.min_temp = self.data['min_temp']
#
# Cell In[48], line 7, in CountryData.__init__(self, filename)
#       5 self.country = self.data['Country']
#       6 self.__avg_temp = self.data['avg_temp']
# ----> 7 self.comfort = self.is_comfort()
#
# Cell In[48], line 16, in CountryData.is_comfort(self)
#      15 def is_comfort(self):
# ---> 16     return self.avg_temp > 25
#
# AttributeError: 'CountryDataWithMinTemp' object has no attribute 'avg_temp'

# %%
print(data1)  # print(str(data1))
print(data1 < data2)
print(data1 <= data2)
print(data1 > data2)
print(data1 >= data2)
print(data1 + data2)
# Out:
# <__main__.CountryData object at 0x000001F2E29A8E10>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 print(data1)  # print(str(data1))
# ----> 2 print(data1 < data2)
#       3 print(data1 <= data2)
#       4 print(data1 > data2)
#
# TypeError: '<' not supported between instances of 'CountryData' and 'CountryData'

# %%
class MyClass:
    @property
    def my_word(self):
        return 'hello'

    def act(self):
        print('hello')


qqq = MyClass()
qqq.act()
qqq.my_word
# Out:
# hello
# 'hello'
