# %% [raw]
# while loop- цикл коллекции

# %%
from pycparser.ply.yacc import resultlimit
from setuptools.unicode_utils import try_encode

i = 0

while i < 5:
    print('hello')
    i += 1

print('The end')
# Out:
# hello
# hello
# hello
# hello
# hello
# The end

# %%
while True:
    user_input = input('Enter something: ')
    if user_input == 'exit':
        break
    elif user_input == 'skip':
        print('skipping......')
        continue
    elif len(user_input) > 10:
        print('Your input is too long')
    else:
        print('input is ok')

print('Good bye!')
# Out:
# input is ok
# skipping......
# Good bye!

# %%
text = 'Sed vitae justo malesuada, commodo libero eu, bibendum mauris.'

words = text.split()
fin_words = []
for word in words:
    if word == 'end':
        break
    elif 'o' in word:
        print(word)
        continue
    fin_words.append(word)

print(' '.join(fin_words))
# Out:
# justo
# commodo
# libero
# Sed vitae malesuada, eu, bibendum mauris.

# %%
Functions
Это самые основные программные структуры в языке Python, позволяющие многократное использование программного кода и уменьшающие его избыточность. Так же позволяют разбить сложную систему на достаточно простые и легко управляемые части. Они могут принимать аргументы и возвращать результаты выполнения.

# %%
a = 1
b = 5
c = 4
d = 7
y = 1


main_number = 47

if y == 0:
    print(a)
else:
    print(a + main_number)
if y == 0:
    print(b)
else:
    print(b + main_number)
if y == 0:
    print(c)
else:
    print(c + main_number)
if y == 0:
    print(d)
else:
    print(d + main_number)
# Out:
# 48
# 52
# 51
# 54

# %%
a = 1
b = 5
c = 4
d = 7
y = 1

main_number = 47

def calc(numb):
    if y == 0:
        print(numb)
    else:
        print(numb + main_number)

calc(a)
calc(b)
calc(c)
calc(d)
# Out:
# 48
# 52
# 51
# 54

# %%
a = 1
b = 5
c = 4
d = 7
y = 1

main_number = 47

def calc(numb):
    if y == 0:
        return numb
    else:
        result = numb + main_number
        return result

print(calc(a))
#result_b = calc(b)
# print(result_b)
#calc(c)
#calc(d)
_ = 1
# Out:
# 48

# %%
def print_words(first, second, third, fourth, fifth):
    print(f'The first word is {first}, second word is {second}, {third}, {fourth}, {fifth}')

print_words('one', 'two', 'three', 'four', 'five')
print_words(fifth='five', third='three', fourth='four', first='one', second='two')
# Out:
# The first word is one, second word is two, three, four, five
# The first word is one, second word is two, three, four, five

# %%
def power(number, degree=2):
    return number ** degree

print(power(2))
print(power(2, 3))
# Out:
# 4
# 8

# %%
def example(e, f, g, ff='one', gg='two'):
    print(e, f, g, ff, gg)

example(2, 3, 6, gg=23)
example(3, 5, 7)
# Out:
# 2 3 6 one 23
# 3 5 7 one two

# %%
def sum_all(*args):
    # print(args)
    # result = 0
    # for x in args:
    #     result += x
    # return result
    return sum(args)

print(sum_all(1, 4, 6, 5, 7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 4
#       1 def sum_all(*args):
#       2     return sum(args)
# ----> 4 print(sum_all(1, 4, 6))
#
# Cell In[48], line 2, in sum_all(*args)
#       1 def sum_all(*args):
# ----> 2     return sum(args)
#
# Cell In[14], line 11, in sum(numb)
#      10 def sum(numb):
# ---> 11     print(numb + main_number)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
def price_list(title, price):
    print(f'Product {title} price is {price}')

price_list('iphone', 2000)
price_list('laptop', 1000)
# Out:
# Product iphone price is 2000
# Product laptop price is 1000

# %%
def price_list(**kwargs):
    for title, price in kwargs.items():
        print(f'Product {title} price is {price}')

price_list(iphone=2000, laptop=1000, xiaomi=5000, monitor=100000)
# Out:
# Product iphone price is 2000
# Product laptop price is 1000
# Product xiaomi price is 5000
# Product monitor price is 100000
